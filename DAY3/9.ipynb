# %%
#Write a function that returns multiple values (e.g., min and max of 3 numbers)

def compare(a,b,c):
    return min(a,b,c), max(a,b,c)

minimum,maximum= compare(39,98,66)

print("Maximum=",maximum)
print("Minimum=",minimum)
# Out:
# Maximum= 98
# Minimum= 39
