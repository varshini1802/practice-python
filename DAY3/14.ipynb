# %%
#Write a well-documented function (with docstring) that converts a value between units (Medium)

def km_to_meter(km):
    """kilometer to meter"""
    return km*1000

print(km_to_meter(6))
# Out:
# 6000
