# %%
#Write a function to check if a number is even or odd 

def even_odd(num):
    if num%2==0:
        print("even")
    else:
        print("odd")

num=int(input("enter a number"))
even_odd(num)
# Out:
# even
