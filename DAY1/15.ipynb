# %%
#Build a basic 3-question quiz program that calculates the final score 
score=0
ans1=input("How many colors are in Rainbow? \na.6 \nb.7 \nc.10")
if ans1=="b" or ans1=="7":
    score+=1
    print("Correct!!")
    print("Score: ",score)
    print("\n")
else:
    print("incorrect.. answer is 7")
    print("score",score)
    print("\n")

ans2=input("Which is India's national animal \na.Lion \nb.elephant \nc.tiger")
if ans2=="c" or ans2=="tiger":
    score+=1
    print("Correct!!")
    print("Score: ",score)
    print("\n")
else:
    print("incorrect.. answer is tiger")
    print("score",score)
    print("\n") 

ans3=input("Identify an insect in the following? \na.Ladybug \nb.Hen \nc.Parrot")
if ans3=="a" or ans3=="Ladybug":
    score+=1
    print("Correct!!")
    print("Score: ",score)
    print("\n")
else:
    print("incorrect.. answer is Ladybug")
    print("score",score)
    print("\n")


if score<=1:
    print("your total score:",score)
elif score==2:
    print("your total score:",score)
else:
    print("your total score:",score)
# Out:
# Correct!!
# Score:  1
#
#
# incorrect.. answer is tiger
# score 1
#
#
# incorrect.. answer is Ladybug
# score 1
#
#
# your total score: 1
