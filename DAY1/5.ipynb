# %%
#Convert temperature from Celsius to Fahrenheit and vice versa
celsius=float(input("enter temperature in Celsius"))
farenheit=float(input("enter temperature in Farenheit"))

def celsius_to_farenheit(celsius):
    return(celsius*9/5)+32
def farenheit_to_celsius(farenheit):
    return(farenheit-32)*5/9

print(celsius,"C is equal to",round(celsius_to_farenheit(celsius),2),"degree F")
print(farenheit,"F is equal to",round(farenheit_to_celsius(farenheit),2),"degree C")
# Out:
# 32.0 C is equal to 89.6 degree F
# 43.0 F is equal to 6.11 degree C
