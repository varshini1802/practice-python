# %%
#Take three numbers and print the largest and smallest without using built-in max/min 

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))
print("the given numbers:",a,b,c)
if a>b and a>c:
    print("The largest number is",a)
elif b>a and b>c:
    print("The largest number is",b)
else:
    print("The largest number is",c)            #....largest


if a<b and a<c:
    print("The smallest number is",a)
elif b<a and b<c:
    print("The smallest number is",b)
else:
    print("The smallest number is",c)
# Out:
# the given numbers: 25.0 47.0 35.0
# The largest number is 47.0
# The smallest number is 25.0
