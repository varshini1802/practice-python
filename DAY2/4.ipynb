# %%
#simple square pattern 

x=int(input("enter the size:"))

for i in range(x):
    for j in range(x):
        print("*", end="  ")
    print()
# Out:
# *  *  *  *
# *  *  *  *
# *  *  *  *
# *  *  *  *
