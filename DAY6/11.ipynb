# %%
#Use Python's built-in math module to solve basic geometry problems (Easy)

#area of circle 

import math
r=8
area=math.pi*r*r
print("Area of circle-",area)
# Out:
# Area of circle- 201.06192982974676

# %%
import math

math.sqrt(64)
# Out:
# 8.0
