# %%
#Take a number as input and handle invalid (non-numeric) input using exception handling (Easy)

try:
    num=int(input("enter a number"))
    print("your input",num)
except ValueError:
    print("Pls Enter a number")
# Out:
# Pls Enter a number
