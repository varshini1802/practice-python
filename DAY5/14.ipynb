# %%
#Build a simple contact book using a dictionary (add, search, delete, display) (Hard)

contacts = {}

while True:
    print("\n1. Add")
    print("2. Search")
    print("3. Delete")
    print("4. Display")
    print("5. Exit")

    choice = int(input("Enter choice: "))

    if choice == 1:
        name = input("Enter name: ")
        phone = input("Enter phone: ")
        contacts[name] = phone
        print("Contact added")

    elif choice == 2:
        name = input("Enter name: ")
        print(contacts.get(name, "Contact not found"))

    elif choice == 3:
        name = input("Enter name: ")
        if name in contacts:
            del contacts[name]
            print("Contact deleted")
        else:
            print("Contact not found")

    elif choice == 4:
        print(contacts)

    elif choice == 5:
        break

    else:
        print("Invalid choice")
# Out:
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
# Contact added
#
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
# Contact added
#
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
# Contact added
#
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
# Contact not found
#
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
# 9071501974
#
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
# {'Varsh': '7625038376', 'C': '9071501974', 'basu': '9343044626'}
#
# 1. Add
# 2. Search
# 3. Delete
# 4. Display
# 5. Exit
