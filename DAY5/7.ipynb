# %%
#Create a set and demonstrate union, intersection, and difference

a={45,67,24,78,90}
b={56,78,31,90,66}

print(a.union(b))
print(a.intersection(b))
print(a.difference(b))
# Out:
# {66, 67, 56, 45, 78, 24, 90, 31}
# {90, 78}
# {24, 67, 45}
