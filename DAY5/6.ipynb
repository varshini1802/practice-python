# %%
#Update, add, and delete a dictionary key-value pair
students={
    "Anita":87,
    "Bob":56,
    "David":85
}

students["Bob"]=80
students["Rahul"]=97
del students["David"]

print(students)
# Out:
# {'Anita': 87, 'Bob': 80, 'Rahul': 97}
