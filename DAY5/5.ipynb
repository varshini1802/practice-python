# %%
#Create a dictionary of student names and marks, then print each pair
students={
    "Anita":87,
    "Bob":56,
    "David":85
}
for name,marks in students.items():
    print(name,marks)
# Out:
# Anita 87
# Bob 56
# David 85
