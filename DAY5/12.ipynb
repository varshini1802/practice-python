# %%
#Use dictionary comprehension to create a dictionary of numbers mapped to their cubes (Medium)

cubes={x: x*x*x for x in range(1,11)}
print(cubes)
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}
