# %%
#Calculate total and average of a list using built-in functions

list=[45,76,98,88,45,34]

total=sum(list)
average=total/len(list)

print("Total sum",total)
print("Average",average)
# Out:
# Total sum 386
# Average 64.33333333333333
