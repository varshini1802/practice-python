# %%
#Create a tuple of your favourite movies and access elements using indexing 

movies=("Dhurandhar","Mungaru Male","Hi nanna")

print(movies[0])
print(movies[1])
print(movies[2])
# Out:
# Dhurandhar
# Mungaru Male
# Hi nanna
