# %%
#Format and print a sentence using f-strings

name = input("Enter your name: ")
age = int(input("Enter your age: "))
college = input("Enter your college: ")

print(f"My name is {name}, I'm {age} years old and i'm studying in {college}")
# Out:
# My name is Varshini, I'm 21 years old and i'm studying in DSU
