# %%
#Take a full name as input and print first name and last name separately

name=input("enter your full name")

x=name.split()
print("first name:",x[0])
print("last name:",x[-1])
# Out:
# first name: Devdutt
# last name: Padikkal
