# %%
#Build a simple Mad Libs program that takes several word inputs and formats them into a story
name = input("Enter a name: ")
animal = input("Enter an animal: ")
place = input("Enter a place: ")
food = input("Enter a food: ")
action = input("Enter an action: ")

print(f"One day {name} went to {place} to taste his favourite {food}. On his way back to the Hotel room, he saw funny dancing {animal} which made him {action}")
# Out:
# One day Rohan went to Mysuru to taste his favourite Dose. On his way back to the Hotel room, he saw funny dancing Gorrilla which made him laugh
