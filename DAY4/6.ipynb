# %%
#Check whether a string starts or ends with a particular word

sentence = input("Enter a sentence: ")
word = input("Enter the word: ")

if sentence.startswith(word):
    print("Yes, it starts with",word)
elif sentence.endswith(word):
    print("Yes, it ends with",word)
else:
    print("Neither starts or ends with",word)
# Out:
# Yes, it ends with happy
